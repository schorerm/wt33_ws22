# %% [markdown]
# # Probeklausur WT33 Wissenschaftliches Arbeiten und Statistische Datenanalyse
# ## Teilbereich Statistische Datenanalyse
#
# ### Freitag, 14.01.2022,  10:15 Uhr - 11:00 Uhr,  Dauer: 45 Minuten
#
# ### 50 Punkte
#
# ### Regeln
# - Alle Hilfsmittel sind erlaubt
# - Eine Kommunikation der Prüfungsteilnehmer untereinander ist während der Prüfung nicht erlaubt
# - Der Bearbeitungszeitraum muss selbständig eingehalten werden. Die Zeit startet sobald alle einführenden Hinweise gegeben wurden.
#
# - Diese Regeln müssen von den Prüfungsteilnehmern eingehalten werden und werden durch die Teilnahme an der Prüfung automatisch bestätigt.

# %% [markdown]
# Name:

# %% [markdown]
# Matrikelnummer:

# %% [markdown]
# ## Hinweise
#
# ### Während der Bearbeitung:
# - Lesen Sie die Angaben vollständig.
# - Geben Sie für alle notwendigen Lösungsschritte den geeigneten Python Code an.
# - Verwenden Sie beliebig viele Zwischenschritte oder Teillösungen.
# - Erzeugen Sie so viele Zellen im Notebook, wie Sie benötigen. Es gibt keine Obergrenze.
#
#
#
#
#
# ### Bei Problemen:
#
# - Ihr Code ist nicht lauffähig bzw. Fehler lassen sich nicht beheben.
#     - Lösung: Lassen Sie den nicht-lauffähigen Code im Notebook und versuchen Sie Ihren Gedankengang zu Lösung des Problems schriftlich darzulegen. Benutzen Sie dazu entweder Kommentare (Code-Zeile beginnt mit #) oder eine zusätzliche Markdown-Zelle.
#
#
# - Eine Zelle lässt sich nicht ausführen:
#
#     - Kein Kernel ausgewählt
#         - Lösung: Python Kernel auswählen
#
#         ![Fehlermeldung](img/binder_error_kernel1.png)
#
#         ![Fehlermeldung](img/binder_error_kernel2.png)
#
#
#     - Falscher Zelltyp gewählt
#         - Lösung: Den richtigen Zelltyp in der Menuleiste auswählen. Zellen mit Python-Code haben zwei rechteckige Klammern an der linken Seite: []
#
#         ![Fehlermeldung](img/binder_celltype1.png)
#
#         ![Fehlermeldung](img/binder_celltype2.png)
#
#
# - Binder Session endet/Verbindung bricht ab (z.B. nach 10 Minuten ohne Aktivität)
#     Lösung:
#     1. Browser *NICHT* schließen.
#
#     2. Bestätigen Sie ggf. die Fehlermeldung mit "Dismiss"
#
#     ![Fehlermeldung](img/binder_error.png)
#
#     3. Speichern Sie den ihr Notebook im Browser Speicher:
#
#     ![Fehlermeldung](img/binder_error2.png)
#
#     ![Fehlermeldung](img/binder_error3.png)
#
#     4. Öffnen Sie einen neuen Tab
#
#     5. Stellen Sie die Verbindung zum Notebook erneut her, indem Sie den Link aus Moodle zur Prüfung aufrufen bzw. in die Adresszeile des neuen Tabs einfügen.
#
#     6. Stellen Sie das ursprüngliche Notebook aus dem Browserspeicher wieder her:
#
#     ![Fehlermeldung](img/binder_error5.png)
#
#     ![Fehlermeldung](img/binder_error6.png)
#
#
#
#
# ### Nach Ablauf der Bearbeitungszeit:
# - Laden Sie das Notebook mit dem Download-Button auf Ihre lokale Festplatte herunter.
#
# ![Download](img/binder_Download.png)
#
# - Benennen Sie die Datei wie folgt: NACHNAME_MATRIKELNUMMER_WT33_PK_WS21.ipynb
#
# - Geben Sie das Notebook ab indem Sie die Datei (bzw. ggf. auch mehrere Dateien) in der Aufgabe in Moodle hochladen.

# %% [markdown]
# ## Aufgaben
#
# ***Ab hier geht es los - Viel Erfolg!***

# %% [markdown]
# ### Aufgabe 0
#
# Vorbereitung [0 Punkte]

# %%
import pandas as pd
import matplotlib.pyplot as plt
nba = pd.read_csv("nba_all_elo.csv")
pd.set_option("display.max.columns", None)

# %% [markdown]
# ### Aufgabe 1
#
# [2 Punkte] Geben Sie die ersten 15 Zeilen des DataFrames aus.

# %%
#Lösung
nba.head(15)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# 11          6  194611030CLR   NBA        0     1947  11/3/1946           1
# 12          7  194611040PIT   NBA        0     1947  11/4/1946           2
# 13          7  194611040PIT   NBA        1     1947  11/4/1946           2
# 14          8  194611050BOS   NBA        0     1947  11/5/1946           2
#
#     is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0             0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# 1             0     NYK        Knicks   68  1300.0000  1306.7233  41.705170
# 2             0     CHS         Stags   63  1300.0000  1309.6521  42.012257
# 3             0     NYK        Knicks   47  1306.7233  1297.0712  40.692783
# 4             0     DTF       Falcons   33  1300.0000  1279.6189  38.864048
# 5             0     WSC      Capitols   50  1300.0000  1320.3811  43.135952
# 6             0     BOS       Celtics   53  1300.0000  1294.8458  40.459381
# 7             0     PRO  Steamrollers   59  1300.0000  1305.1542  41.540619
# 8             0     PIT       Ironmen   51  1300.0000  1295.3092  40.507980
# 9             0     STB       Bombers   56  1300.0000  1304.6908  41.492020
# 10            0     TRH       Huskies   60  1293.2767  1286.1534  39.548164
# 11            0     CLR        Rebels   71  1300.0000  1307.1233  41.747120
# 12            0     PIT       Ironmen   56  1295.3092  1277.9456  38.689037
# 13            0     WSC      Capitols   71  1320.3811  1337.7448  44.946995
# 14            0     BOS       Celtics   55  1294.8458  1288.4139  39.785030
#
#    opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 0     NYK        Knicks       68  1300.0000  1306.7233             H
# 1     TRH       Huskies       66  1300.0000  1293.2767             A
# 2     NYK        Knicks       47  1306.7233  1297.0712             H
# 3     CHS         Stags       63  1300.0000  1309.6521             A
# 4     WSC      Capitols       50  1300.0000  1320.3811             H
# 5     DTF       Falcons       33  1300.0000  1279.6189             A
# 6     PRO  Steamrollers       59  1300.0000  1305.1542             A
# 7     BOS       Celtics       53  1300.0000  1294.8458             H
# 8     STB       Bombers       56  1300.0000  1304.6908             A
# 9     PIT       Ironmen       51  1300.0000  1295.3092             H
# 10    CLR        Rebels       71  1300.0000  1307.1233             A
# 11    TRH       Huskies       60  1293.2767  1286.1534             H
# 12    WSC      Capitols       71  1320.3811  1337.7448             H
# 13    PIT       Ironmen       56  1295.3092  1277.9456             A
# 14    CHS         Stags       57  1309.6521  1316.0840             H
#
#    game_result  forecast notes
# 0            L  0.640065   NaN
# 1            W  0.359935   NaN
# 2            W  0.631101   NaN
# 3            L  0.368899   NaN
# 4            L  0.640065   NaN
# 5            W  0.359935   NaN
# 6            L  0.359935   NaN
# 7            W  0.640065   NaN
# 8            L  0.359935   NaN
# 9            W  0.640065   NaN
# 10           L  0.351068   NaN
# 11           W  0.648932   NaN
# 12           L  0.606189   NaN
# 13           W  0.393811   NaN
# 14           L  0.620204   NaN

# %% [markdown]
# ### Aufgabe 2
#
# [8 Punkte] Erzeugen Sie einen Dataframe mit der Bezeichnung `celtics_playoffs`, der nur die Playoff-Spiele der Boston Celtics (`team_id` BOS) enthält. Hinweis: Benutzen Sie dazu das Flag in Spalte `is_playoffs`.
#
# Geben Sie außerdem einen Auszug des Dataframes aus (z.B. die ersten 10 Zeilen des DataFrames)

# %%
#Lösung
celtics_playoffs = nba[(nba["team_id"] == 'BOS') & (nba["is_playoffs"] == 1) ]

# %%
celtics_playoffs.head(10)
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1097        549  194803280BOS   NBA        0     1948  3/28/1948          49
# 1102        552  194803310BOS   NBA        0     1948  3/31/1948          50
# 1108        555  194804020BOS   NBA        0     1948   4/2/1948          51
# 3785       1893  195103200BOS   NBA        0     1951  3/20/1951          70
# 3795       1898  195103220NYK   NBA        1     1951  3/22/1951          71
# 4498       2250  195203190BOS   NBA        0     1952  3/19/1952          67
# 4508       2255  195203230NYK   NBA        1     1952  3/23/1952          68
# 4514       2258  195203260BOS   NBA        0     1952  3/26/1952          69
# 5251       2626  195303190SYR   NBA        1     1953  3/19/1953          72
# 5257       2629  195303210BOS   NBA        0     1953  3/21/1953          73
#
#       is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv  \
# 1097            1     BOS  Celtics   72  1312.5914  1304.9589  31.554913
# 1102            1     BOS  Celtics   81  1304.9589  1312.2666  32.283836
# 1108            1     BOS  Celtics   74  1312.2666  1304.6532  31.524557
# 3785            1     BOS  Celtics   69  1506.6257  1488.9506  39.948803
# 3795            1     BOS  Celtics   78  1488.9506  1481.7932  39.198959
# 4498            1     BOS  Celtics  105  1574.9653  1582.4563  48.504478
# 4508            1     BOS  Celtics   97  1582.4563  1578.0449  48.056339
# 4514            1     BOS  Celtics   87  1578.0449  1572.3955  47.479900
# 5251            1     BOS  Celtics   87  1584.0746  1596.8373  50.079281
# 5257            1     BOS  Celtics  111  1596.8373  1602.8749  50.679440
#
#      opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 1097    CHS    Stags       79  1438.3618  1445.9944             H           L
# 1102    CHS    Stags       77  1445.9944  1438.6866             H           W
# 1108    CHS    Stags       81  1438.6866  1446.3000             H           L
# 3785    NYK   Knicks       83  1510.8330  1528.5082             H           L
# 3795    NYK   Knicks       92  1528.5082  1535.6655             A           L
# 4498    NYK   Knicks       94  1579.5975  1572.1066             H           W
# 4508    NYK   Knicks      101  1572.1066  1576.5179             A           L
# 4514    NYK   Knicks       88  1576.5179  1582.1674             H           L
# 5251    SYR   Sixers       81  1646.4547  1633.6920             A           W
# 5257    SYR   Sixers      105  1633.6920  1627.6544             H           W
#
#       forecast notes
# 1097  0.462981   NaN
# 1102  0.441218   NaN
# 1108  0.462052   NaN
# 3785  0.634467   NaN
# 3795  0.309308   NaN
# 4498  0.633899   NaN
# 4508  0.373772   NaN
# 4514  0.642088   NaN
# 5251  0.281965   NaN
# 5257  0.589886   NaN

# %% [markdown]
# **Hinweis**
# Sollten sie Aufgabe 2 nicht gelöst haben so führen Sie bitte folgendes Statment aus, um mit dem korrekten DataFrame weiterzuarbeiten.

# %%
celtics_playoffs = pd.read_csv("celtics.csv")

# %% [markdown]
# ### Aufgabe 3
#
# [3 Punkte] Wie viele Spiele haben die Celtics insgesamt in den Playoffs absolviert?

# %%
#Lösung
celtics_playoffs["game_id"].count()
# Out:
# 601

# %% [markdown]
# ### Aufgabe 4
#
# [4 Punkte] Wie viele Spiele haben die Celtics insgesamt in den Playoffs **gewonnen**?

# %%
#Lösung
celtics_playoffs.loc[celtics_playoffs["game_result"] == "W", "game_id"].count()
# Out:
# pts        37954
# opp_pts    33981
# dtype: int64

# %% [markdown]
# ### Aufgabe 5
#
# [3 Punkte] Erzeugen Sie einen Boxplot, der die Häufigkeitsverteilung der erzielten Punkte der Celtics in diesen Spielen darstellt.

# %%
#Lösung
celtics_playoffs.pts.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aufgabe 6
#
# [6 Punkte] Welche Bedeutung hat der horizontale Strich in der Mitte der Box? Wie wird dieser Lageparameter genannt?
#
# Welche Bedeutung haben die beiden Punkte am oberen Ende der Darstellung? Warum werden sie so dargestellt?
#
# ![Fehlermeldung](img/boxplot.png)

# %% [markdown]
# Antwort:

# %% [markdown]
# `#Lösung`
# Der Strich markiert den mittleren Wert der Datenreihe. 50% der Werte sind größer, 50% kleiner. Der Lageparameter heißt Median.
#
# Die Punkte heißen Ausreißer. Sie werden so dargestellt, da Sie mehr als das 1,5-fache des IQA vom 75% Quantil entfernt sind.

# %% [markdown]
# ### Aufgabe 7
#
# [2 Punkte] Geben Sie den genauen Wert des Lageparameters aus Aufgabe 5 aus.

# %%
#Lösung
celtics_playoffs.pts.median()
# Out:
# 105.0

# %%
celtics_playoffs.pts.min()
# Out:
# 66

# %% [markdown]
# ### Aufgabe 8
#
# [6 Punkte] Gegeben sind die beiden u.g. Code-Fragmente. Was wird hier jeweils berechnet?

# %%
celtics_playoffs[celtics_playoffs["game_result"] == "W"].pts.mean()

# %%
celtics_playoffs[celtics_playoffs["game_result"] == "L"].pts.mean()

# %% [markdown]
# Antwort:

# %% [markdown]
# `#Lösung`
# Es wird das arithmetische Mittel der erzielten Punkte für Boston jeweils für alle Siege und alle Niederlagen getrennt berechnet.

# %% [markdown]
# ### Aufgabe 9
#
# [6 Punkte] Geben Sie ein Statement an, dass die beiden Berechnungen aus Aufgabe 7 vereint und zwei Zeilen auf einmal ausgibt.
#
# Hinweis: Die Berechnung wird nun nicht mehr für explizit festgelegt Werte der Spalte `game_result` durchgeführt sondern für jeden gefundenen Wert gruppenweise erledigt.

# %%
#Lösung
celtics_playoffs.groupby("game_result").pts.mean()
# Out:
# game_result
# L     97.743191
# W    110.331395
# Name: pts, dtype: float64

# %% [markdown]
# ### Aufgabe 10
#
# [3 Punkte] Um die Verteilung der der Gegner in den verlorenen Spielen der Celtics zu analysieren wird Ihnen folgendes Statement vorgelegt. Wieso schlägt das Statement fehl?

# %%
celtics_playoffs[celtics_playoffs["game_result"] == "L"].opp_id.mean()

# %% [markdown]
# Antwort:

# %% [markdown]
# `#Lösung`
# Antwort: Die Spalte `opp_id` ist nominalskaliert. Hier sind Transformationen wie Addition und Division nicht erlaubt.

# %% [markdown]
# ### Aufgabe 11
#
# [4 Punkte] Wie können Sie die Häufigkeitsverteilung der Gegner in den verlorenen Playoffspielen auf einfache Weise veranschaulichen? Geben Sie das passende Statement an.

# %%
#Lösung
celtics_playoffs[celtics_playoffs["game_result"] == "L"].opp_id.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aufgabe 12
#
# [3 Punkte] Ein ähnliches Statement wie in Aufgabe 9 sehen Sie nachfolgend. Es ist zwar lauffähig, jedoch statistisch ohne Aussagekraft. Warum?

# %%
celtics_playoffs[celtics_playoffs["game_result"] == "L"].gameorder.mean()
# Out:
# 26809.272373540854

# %% [markdown]
# Antwort:

# %% [markdown]
# `#Lösung`
# Antwort: Die Spalte `gameorder` ist ordinalskaliert. Hier sind Transformationen wie Addition und Division nicht erlaubt.
