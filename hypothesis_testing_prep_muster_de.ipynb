# %% [markdown]
# # Daten untersuchen mit Pandas und Python für Fortgeschrittene

# %% [markdown]
# ### Daten aus der CSV-Datei lesen
#
# Nun benutzen wir pandas um die [CSV-Datei](https://de.wikipedia.org/wiki/CSV_(Dateiformat)) einzulesen. Damit das funktioniert muss vorher noch das pandas-Paket mit dem `import`-Befehl unter dem Namen `pd` verfügbar gemacht werden.
#
# Dabei wird ein sogenannter [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) mit dem Namen `nba` erzeugt. Vereinfacht kann man sich darunter eine Tabelle mit Spalten und Zeilen vorstellen. DataFrames sind **die** zentralen Datentypen in pandas.
#
# Mit dem Befehl `type()` kann der Datentyp eines jeden Python-Objekts ausgegeben werden.

# %%
import pandas as pd
import numpy as np
nba = pd.read_csv("nba_all_elo.csv")
type(nba)
# Expected:
# <class 'pandas.core.frame.DataFrame'>
# Out:
# pandas.core.frame.DataFrame

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
# 3  1300.0000  1309.6521              A            L  0.368899   NaN
# 4  1300.0000  1320.3811              H            L  0.640065   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # Aufgabe: Finals
# ![finals](./finals.png)
#
# Seit 2005 werden die Playoffs, das Finalturnier der NBA, in einem Wettbewerb im Best-of-Seven Moduls gespielt.
# Eine Finalserie hat also zwischen 4 und 7 Spielen zwischen einer Spielpaarung. Dabei werden die ersten vier Spiele je 2 Spiele am Heimort der ersten Mannschaft und anschließend zwei Spiele am Heimort der anderen Mannschaft gespielt. Danach wird der Spielort pro Spiel gewechselt. Folglich startet eine Mannschaft mit zwei Auswärtsspielen in eines solche Finalserie. Siehe: https://en.wikipedia.org/wiki/NBA_playoffs
#
# ![finals](./finals_PHX_DAL.png)
#
#
#
# Da im Sport Erfahrungen, Binsenweisheiten und andere Mutmaßungen sehr weit verbreitet ist können man sich folgenden Ausspruch vorstellen:
#
# >"Das Auswärtsteam wird eine Serie eher gewinnen wenn Sie das erste Auswärtsspiel (Spiel 1 der Serie) gewinnt und das zweite verliert als anders herum."
#
# Da wir die Daten zu allen Spielen haben lässt sich das ja nun eigentlich sehr einfach nachprüfen.
#
# In den nächsten beiden Einheiten werden wird die Daten soweit aufbereiten um diese Hypothese zu testen. Dazu müssen wir nun erst einmal die Serien in den Daten nachbilden.

# %% [markdown]
# ## Vorbereitung

# %% [markdown]
# 1. Alle Playoffspiele ab 2015 extrahieren

# %% [markdown]
# Dazu Filter auf `year_id` und `is_playoffs` verwenden:

# %%
playoffs2005= nba[
    (nba["is_playoffs"] == 1) & 
    (nba["year_id"] >= 2005) # Datum von
    ]
playoffs2005
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 100346      50174  200504230BOS   NBA        0     2005  4/23/2005
# 100347      50174  200504230BOS   NBA        1     2005  4/23/2005
# 100348      50175  200504230DAL   NBA        0     2005  4/23/2005
# 100349      50175  200504230DAL   NBA        1     2005  4/23/2005
# 100350      50176  200504230DET   NBA        0     2005  4/23/2005
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 100346          83            1     BOS    Celtics  ...  44.004639     IND
# 100347          83            1     IND     Pacers  ...  46.631470     BOS
# 100348          83            1     DAL  Mavericks  ...  58.357548     HOU
# 100349          83            1     HOU    Rockets  ...  59.455257     DAL
# 100350          83            1     DET    Pistons  ...  53.457451     PHI
# ...            ...          ...     ...        ...  ...        ...     ...
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 100346     Pacers       82  1564.4844  1550.8414              H            W
# 100347    Celtics      102  1511.8661  1525.5090              A            L
# 100348    Rockets       98  1669.1071  1686.3287              H            L
# 100349  Mavericks       86  1690.6172  1673.3955              A            W
# 100350     Sixers       85  1500.2852  1493.7009              H            W
# ...           ...      ...        ...        ...            ...          ...
# 126309   Warriors      103  1790.9591  1809.9791              H            L
# 126310  Cavaliers       91  1704.3949  1700.7391              H            W
# 126311   Warriors      104  1809.9791  1813.6349              A            L
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 100346  0.567768   NaN
# 100347  0.432232   NaN
# 100348  0.668070   NaN
# 100349  0.331930   NaN
# 100350  0.772712   NaN
# ...          ...   ...
# 126309  0.546572   NaN
# 126310  0.765565   NaN
# 126311  0.234435   NaN
# 126312  0.481450   NaN
# 126313  0.518550   NaN
#
# [1850 rows x 23 columns]

# %% [markdown]
# 2. Alle Series identifizieren und zu den Spielen als neue Spalte `series` zurordnen. Inhalt soll sein teamid1_teamid2 also z.B. `BOS_LAL` für eine Serie zwischen Boston und Los Angeles.

# %% [markdown]
# Mit der loc-Funktion alle Zeilen (:) und due neue Spalte `series` selektieren. Inhalt der neuen SPalte wird `team_id` verkettet mit `opp_id`.

# %%
playoffs2005.loc[:,"series"] = playoffs2005["team_id"].str.cat(playoffs2005["opp_id"], sep ="_")
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# 3. Alle Spiele innerhalb einer Series nummerieren. Tipp: Benutzen Sie die Funktion rank() bzw. groupby() und  GroupBy.rank()
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rank.html bzw.
# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.GroupBy.rank.html#pandas.core.groupby.GroupBy.rank

# %% [markdown]
# Datum konvertieren.

# %%
playoffs2005["date_game"] = pd.to_datetime(playoffs2005["date_game"])
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Kopie anlegen und Spiele pro Serie und Jahr (`groupby()`) nach Datum (`date_game`) nummerieren (`rank()`).

# %%
playoffs2005_grouped = playoffs2005
playoffs2005_grouped["series_game"]=playoffs2005.groupby(["year_id","series"])["date_game"].rank()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Zum Test zwei Serien betrachten: Dallas vs Houston 2005 und 2015

# %%
playoffs2005_grouped[playoffs2005_grouped["series"] == "DAL_HOU"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 100348      50175  200504230DAL   NBA        0     2005 2005-04-23
# 100364      50183  200504250DAL   NBA        0     2005 2005-04-25
# 100379      50190  200504280HOU   NBA        1     2005 2005-04-28
# 100393      50197  200504300HOU   NBA        1     2005 2005-04-30
# 100407      50204  200505020DAL   NBA        0     2005 2005-05-02
# 100423      50212  200505050HOU   NBA        1     2005 2005-05-05
# 100430      50216  200505070DAL   NBA        0     2005 2005-05-07
# 126156      63079  201504180HOU   NBA        1     2015 2015-04-18
# 126174      63088  201504210HOU   NBA        1     2015 2015-04-21
# 126190      63096  201504240DAL   NBA        0     2015 2015-04-24
# 126206      63104  201504260DAL   NBA        0     2015 2015-04-26
# 126218      63110  201504280HOU   NBA        1     2015 2015-04-28
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_fran  opp_pts  \
# 100348          83            1     DAL  Mavericks  ...   Rockets       98
# 100364          84            1     DAL  Mavericks  ...   Rockets      113
# 100379          85            1     DAL  Mavericks  ...   Rockets      102
# 100393          86            1     DAL  Mavericks  ...   Rockets       93
# 100407          87            1     DAL  Mavericks  ...   Rockets      100
# 100423          88            1     DAL  Mavericks  ...   Rockets      101
# 100430          89            1     DAL  Mavericks  ...   Rockets       76
# 126156          83            1     DAL  Mavericks  ...   Rockets      118
# 126174          84            1     DAL  Mavericks  ...   Rockets      111
# 126190          85            1     DAL  Mavericks  ...   Rockets      130
# 126206          86            1     DAL  Mavericks  ...   Rockets      109
# 126218          87            1     DAL  Mavericks  ...   Rockets      103
#
#         opp_elo_i  opp_elo_n game_location game_result  forecast  notes  \
# 100348  1669.1071  1686.3287             H           L  0.668070    NaN
# 100364  1686.3287  1692.7972             H           L  0.622741    NaN
# 100379  1692.7972  1683.3229             A           W  0.326388    NaN
# 100393  1683.3229  1674.3434             A           W  0.350808    NaN
# 100407  1674.3434  1670.7961             H           W  0.654569    NaN
# 100423  1670.7961  1681.7832             A           L  0.384316    NaN
# 100430  1681.7832  1663.4641             H           W  0.634954    NaN
# 126156  1639.3665  1644.2307             A           L  0.267220    NaN
# 126174  1644.2307  1649.4286             A           L  0.256398    NaN
# 126190  1649.4286  1654.3431             H           L  0.506668    NaN
# 126206  1654.3431  1642.4836             H           W  0.492524    NaN
# 126218  1642.4836  1646.9078             A           L  0.260251    NaN
#
#          series series_game
# 100348  DAL_HOU         1.0
# 100364  DAL_HOU         2.0
# 100379  DAL_HOU         3.0
# 100393  DAL_HOU         4.0
# 100407  DAL_HOU         5.0
# 100423  DAL_HOU         6.0
# 100430  DAL_HOU         7.0
# 126156  DAL_HOU         1.0
# 126174  DAL_HOU         2.0
# 126190  DAL_HOU         3.0
# 126206  DAL_HOU         4.0
# 126218  DAL_HOU         5.0
#
# [12 rows x 25 columns]

# %% [markdown]
# 4. Die Anzahl der gewonnen Spiele in der Serie berechnen. in die Spalten `num_series_wins` bzw- `opp_num_series_wins` eintragen. Danach alle Ergebnisse der Serien finden und die `team_id` der Siegermannschaft als neue Spalte `series_winner` eintragen

# %% [markdown]
# Per `groupby()` und `count()` die Anzahl der Siege und Niederlagen zählen. Achtung: Immer aus Perspektive der Heimmannschaft. Spalten anschließend entsprechend benennen.

# %%
serieswins = playoffs2005[playoffs2005["game_result"]=='W'].groupby(["year_id","series"])["date_game"].count()
serieswins.name = 'num_series_wins'

# %%
serieslosses = playoffs2005[playoffs2005["game_result"]=='L'].groupby(["year_id","series"])["date_game"].count()
serieslosses.name = 'opp_series_wins'

# %% [markdown]
# Die Funktion `merge()` verbindet zwei DataFrames anhand einer oder mehreren Schlüsselspalten. Hier werden alle Spiele mit den zuvor ermittelten Kennzahlen zu Siegen und Niederlagen verbunden. Zu jedem Spiel gibt es also nun eine Information zu der übergeordneten Series.

# %%
playoffs2005_merged = pd.merge(left=playoffs2005_grouped,right=serieswins,on=["year_id","series"])
playoffs2005_merged = pd.merge(left=playoffs2005_merged,right=serieslosses,on=["year_id","series"])

# %% [markdown]
# Die neue Spalte `series_winner` wird abhängig vom Sieg/Niederlagen-Verhältnis entweder mit dem Heim oder dem Auswärtsteam gefüllt.

# %%
playoffs2005_merged.loc[playoffs2005_merged['num_series_wins'] > playoffs2005_merged['opp_series_wins'], 'series_winner'] = playoffs2005_merged["team_id"]
playoffs2005_merged.loc[playoffs2005_merged['num_series_wins'] < playoffs2005_merged['opp_series_wins'], 'series_winner'] =  playoffs2005_merged["opp_id"]

# %% [markdown]
# Inhalte überprüfen:

# %%
playoffs2005_merged.tail(20)
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1606      63147  201505230HOU   NBA        1     2015 2015-05-23          95
# 1607      63149  201505250HOU   NBA        1     2015 2015-05-25          96
# 1608      63151  201505270GSW   NBA        0     2015 2015-05-27          97
# 1609      63143  201505190GSW   NBA        1     2015 2015-05-19          95
# 1610      63145  201505210GSW   NBA        1     2015 2015-05-21          96
# 1611      63147  201505230HOU   NBA        0     2015 2015-05-23          97
# 1612      63149  201505250HOU   NBA        0     2015 2015-05-25          98
# 1613      63151  201505270GSW   NBA        1     2015 2015-05-27          99
# 1614      63152  201506040GSW   NBA        1     2015 2015-06-04          97
# 1615      63153  201506070GSW   NBA        1     2015 2015-06-07          98
# 1616      63154  201506090CLE   NBA        0     2015 2015-06-09          99
# 1617      63155  201506110CLE   NBA        0     2015 2015-06-11         100
# 1618      63156  201506140GSW   NBA        1     2015 2015-06-14         101
# 1619      63157  201506170CLE   NBA        0     2015 2015-06-16         102
# 1620      63152  201506040GSW   NBA        0     2015 2015-06-04          98
# 1621      63153  201506070GSW   NBA        0     2015 2015-06-07          99
# 1622      63154  201506090CLE   NBA        1     2015 2015-06-09         100
# 1623      63155  201506110CLE   NBA        1     2015 2015-06-11         101
# 1624      63156  201506140GSW   NBA        0     2015 2015-06-14         102
# 1625      63157  201506170CLE   NBA        1     2015 2015-06-16         103
#
#       is_playoffs team_id    fran_id  ...  opp_elo_n  game_location  \
# 1606            1     GSW   Warriors  ...  1643.4324              A
# 1607            1     GSW   Warriors  ...  1658.9934              A
# 1608            1     GSW   Warriors  ...  1654.6359              H
# 1609            1     HOU    Rockets  ...  1789.7388              A
# 1610            1     HOU    Rockets  ...  1791.2300              A
# 1611            1     HOU    Rockets  ...  1813.4543              H
# 1612            1     HOU    Rockets  ...  1797.8933              H
# 1613            1     HOU    Rockets  ...  1802.2509              A
# 1614            1     CLE  Cavaliers  ...  1806.2035              A
# 1615            1     CLE  Cavaliers  ...  1797.5032              A
# 1616            1     CLE  Cavaliers  ...  1790.9591              H
# 1617            1     CLE  Cavaliers  ...  1809.9791              H
# 1618            1     CLE  Cavaliers  ...  1813.6349              A
# 1619            1     CLE  Cavaliers  ...  1822.2881              H
# 1620            1     GSW   Warriors  ...  1708.1705              H
# 1621            1     GSW   Warriors  ...  1716.8708              H
# 1622            1     GSW   Warriors  ...  1723.4149              A
# 1623            1     GSW   Warriors  ...  1704.3949              A
# 1624            1     GSW   Warriors  ...  1700.7391              H
# 1625            1     GSW   Warriors  ...  1692.0859              A
#
#       game_result  forecast notes   series  series_game  num_series_wins  \
# 1606            W  0.536737   NaN  GSW_HOU          3.0                4
# 1607            L  0.599427   NaN  GSW_HOU          4.0                4
# 1608            W  0.798222   NaN  GSW_HOU          5.0                4
# 1609            L  0.222043   NaN  HOU_GSW          1.0                1
# 1610            L  0.217323   NaN  HOU_GSW          2.0                1
# 1611            L  0.463263   NaN  HOU_GSW          3.0                1
# 1612            W  0.400573   NaN  HOU_GSW          4.0                1
# 1613            L  0.201778   NaN  HOU_GSW          5.0                1
# 1614            L  0.250779   NaN  CLE_GSW          1.0                2
# 1615            W  0.242326   NaN  CLE_GSW          2.0                2
# 1616            W  0.527843   NaN  CLE_GSW          3.0                2
# 1617            L  0.546572   NaN  CLE_GSW          4.0                2
# 1618            L  0.234435   NaN  CLE_GSW          5.0                2
# 1619            L  0.481450   NaN  CLE_GSW          6.0                2
# 1620            W  0.749221   NaN  GSW_CLE          1.0                4
# 1621            L  0.757674   NaN  GSW_CLE          2.0                4
# 1622            L  0.472157   NaN  GSW_CLE          3.0                4
# 1623            W  0.453428   NaN  GSW_CLE          4.0                4
# 1624            W  0.765565   NaN  GSW_CLE          5.0                4
# 1625            W  0.518550   NaN  GSW_CLE          6.0                4
#
#       opp_series_wins series_winner
# 1606                1           GSW
# 1607                1           GSW
# 1608                1           GSW
# 1609                4           GSW
# 1610                4           GSW
# 1611                4           GSW
# 1612                4           GSW
# 1613                4           GSW
# 1614                4           GSW
# 1615                4           GSW
# 1616                4           GSW
# 1617                4           GSW
# 1618                4           GSW
# 1619                4           GSW
# 1620                2           GSW
# 1621                2           GSW
# 1622                2           GSW
# 1623                2           GSW
# 1624                2           GSW
# 1625                2           GSW
#
# [20 rows x 28 columns]
